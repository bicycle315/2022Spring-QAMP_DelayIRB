# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
belem_bigcx=[0.0398, 0.0336, 0.1117]
belem_bigCLE=[0.007538, 0.007538, 0.006137]
belem_biy=[-0.0198, -0.01260, -0.937]
belem_bigd=[0.02, 0.0210, 0.018]

guadalupe_cx=[0.0072,0.0113,0.0114]
guadalupe_y=[0.1308, 0.0327, 0.0035]
guadalupe_CLE=[0.0004971, 0.004214, 0.007621]
guadalupe_d=[0.138, 0.044,0.0149]

belem_cx=[0.0118, 0.0107, 0.0110, 0.0127]
belem_y=[0.0028, 0.00179, 0.0020, 0.00379]
belem_CLE=[0.008904, 0.008904, 0.008904, 0.008904]
belem_d=[0.0193, 0.3,0.27, 0.34]

nairobi_cx=[0.0096, 0.00872, 0.0147, 0.0092, 0.0074]
nairobi_y=[0.00687, 0.006521, 0.01139, 0.005357,0.00484]
nairobi_CLE=[0.002726,0.002179, 0.003561, 0.003843,0.002560]
nairobi_d=[0.0197, 0.02, 0.0213, 0.0218, 0.0117]

toronto_cx=[0.00752, 0.00968,0.0088, 0.00627, 0.00858]
toronto_y=[0, 0.003432, 0.005072, 0.003918,0.005043]
toronto_CLE=[0.006865, 0.006284, 0.003728, 0.002352, 0.003538]
toronto_d=[0.009,0.0105, 0.0097, 0.0067, 0.0063]

santiago_cx=[0.026]
santiago_CLE=[0.003152]
santiago_d=[0.021]

kolkata_cx=[0.0039]
kolkata_d=[0.00509]
kolkata_CLE=[0.00553]

brooklyn_cx=[0.0098]
brooklyn_d=[0.009958]
brooklyn_CLE=[0.0148]

# %%
fig = plt.figure(figsize=(12,6))
ax2 = fig.add_subplot(1,2,1)
ax3 = fig.add_subplot(1,2,2)

ax2.scatter(belem_bigcx, belem_bigd, c='red', label='belem_q0,1_q1,2')
ax2.scatter(guadalupe_cx, guadalupe_d, c='orange', label='guadalupe_q0,1_q3,5')
ax2.scatter(belem_cx,belem_d, c='yellow', label='belem_q3,4')
ax2.scatter(nairobi_cx,nairobi_d, c='green', label='nairobi_all')
ax2.scatter(toronto_cx,toronto_d, c='blue',label='toronto_q8,11_q1,4,_q6,7,q16,19')
ax2.scatter(santiago_cx, santiago_d, c='purple',label='santiag_q3,4')
ax2.scatter(kolkata_cx,kolkata_d, c='black', label='kolkata_q23,24')
ax2.scatter(brooklyn_cx,brooklyn_d, c='grey', label='brooklyn_q27,28')
ax2.set_ylabel('2qDelay', c='black')
ax2.set_xlabel('CX', c='black')
ax2.text(0.01, 0.03, '2qDelay>CX')
ax2.text(0.035, 0.03, '2qDelay<CX')
ax2.set_ylim(0,0.3)
ax2.set_xlim(0,0.05)
ax2.plot([0,0.4],[0,0.4], color='black')
ax2.legend(loc='upper right')
ax2.set_title('CX,2qDelay Correlation')

ax3.scatter(belem_bigcx, belem_bigCLE, c='red', label='belem_q0,1_q1,2')
ax3.scatter(guadalupe_cx, guadalupe_CLE, c='orange', label='guadalupe_q0,1_q3,5')
ax3.scatter(belem_cx,belem_CLE, c='yellow', label='belem_q3,4')
ax3.scatter(nairobi_cx,nairobi_CLE, c='green', label='nairobi_all')
ax3.scatter(toronto_cx,toronto_CLE, c='blue',label='toronto_q8,11_q1,4,_q6,7,q16,19')
ax3.scatter(santiago_cx, santiago_CLE, c='purple',label='santiag_q3,4')
ax3.scatter(kolkata_cx,kolkata_CLE, c='black', label='kolkata_q23,24')
ax3.scatter(brooklyn_cx,brooklyn_CLE, c='grey', label='brooklyn_q27,28')
ax3.set_ylim(0,0.3)
ax3.set_xlim(0,0.05)
ax3.set_ylabel('CLE', c='black')
ax3.plot([0,0.4],[0,0.4], color='black')
ax3.set_xlabel('CX', c='black')
ax3.text(0.03, 0.02, 'CLE<CX')
ax3.legend(loc='upper right')
ax3.set_title('CX,CLE Correlation')

plt.show()

# %%
fig = plt.figure(figsize=(12,6))
ax2 = fig.add_subplot(1,2,1)
ax3 = fig.add_subplot(1,2,2)

ax2.scatter(belem_bigcx, belem_bigd, c='red', label='belem_q0,1_q1,2')
ax2.scatter(guadalupe_cx, guadalupe_d, c='orange', label='guadalupe_q0,1_q3,5')
ax2.scatter(belem_cx,belem_d, c='yellow', label='belem_q3,4')
ax2.scatter(nairobi_cx,nairobi_d, c='green', label='nairobi_all')
ax2.scatter(toronto_cx,toronto_d, c='blue',label='toronto_q8,11_q1,4,_q6,7,q16,19')
ax2.scatter(santiago_cx, santiago_d, c='purple',label='santiago_q3,4')
ax2.scatter(kolkata_cx,kolkata_d, c='black', label='kolkata_q23,24')
a
ax2.set_ylabel('2qDelay', c='black')
ax2.set_xlabel('CX', c='black')
ax2.text(0.01, 0.025, '2qDelay>CX')
ax2.text(0.035, 0.025, '2qDelay<CX')
ax2.set_ylim(0,0.03)
ax2.set_xlim(0,0.05)
ax2.plot([0,0.4],[0,0.4], color='black')
ax2.legend(loc='lower right')
ax2.set_title('CX,2qDelay Correlation')

ax3.scatter(belem_bigcx, belem_bigCLE, c='red', label='belem_q0,1_q1,2')
ax3.scatter(guadalupe_cx, guadalupe_CLE, c='orange', label='guadalupe_q0,1_q3,5')
ax3.scatter(belem_cx,belem_CLE, c='yellow', label='belem_q3,4')
ax3.scatter(nairobi_cx,nairobi_CLE, c='green', label='nairobi_all')
ax3.scatter(toronto_cx,toronto_CLE, c='blue',label='toronto_q8,11_q1,4,_q6,7,q16,19')
ax3.scatter(santiago_cx, santiago_CLE, c='purple',label='santiago_q3,4')
ax3.scatter(kolkata_cx,kolkata_d, c='black', label='kolkata_q23,24')
ax3.set_ylim(0,0.03)
ax3.set_xlim(0,0.05)
ax3.set_ylabel('CLE', c='black')
ax3.plot([0,0.4],[0,0.4], color='black')
ax3.set_xlabel('CX', c='black')
ax3.text(0.03, 0.015, 'CLE<CX')
ax3.legend(loc='upper left')
ax3.set_title('CX,CLE Correlation')

plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax=fig.add_subplot(1,1,1)
ax.set_xlim([0.001, 0.12])
ax.set_ylim([-0.1, 0.2])
x = [0.0072,0.0113, 0.012, 0.0398, 0.0336, 0.1117, 0.0118, 0.0127, 0.0096, 0.00872, 0.026, 0.00752, 0.00968, 0.0088, 0.00627]
y = [0.1308, 0.0327, 0.0029, -0.0198, -0.0126, -0.0937, 0.0075, 0.2837, 0.0101, 0.0128, -0.005, 0.00148, 0.00082, 0.0009, 0.00043]
plt.scatter(x,y) 
plt.plot([0,0.12],[0,0], color='red')
plt.plot([0.02,0.02],[-0.1,0.20], color='blue')
plt.text(0, 0.15, '2qDelay>CX', fontdict={'size':20})
plt.text(0.04, -0.05, '2qDelay<CX',fontdict={'size':20})
plt.text(0.015, -0.1, 'CX threshold',fontdict={'size':20,'weight':'bold','color':'blue'})
ax.set_title('CX,2qDelay Correlation')
ax.set_xlabel('CXerror')
ax.set_ylabel('2qDelay-CX')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure(figsize=(10,8))
ax=fig.add_subplot(1,1,1)
ax.set_xlim([0.005, 0.05])
ax.set_ylim([-0.02, 0.02])
x = [0.0072,0.0113, 0.012, 0.0398, 0.0336, 0.1117, 0.0118, 0.0127, 0.0096, 0.00872, 0.026, 0.00752, 0.00968, 0.0088, 0.00627]
y = [0.1308, 0.0327, 0.0029, -0.0198, -0.0126, -0.0937, 0.0075, 0.2837, 0.0101, 0.0128, -0.005, 0.00148, 0.00082, 0.0009, 0.00043]
plt.scatter(x,y) 
plt.plot([0,0.12],[0,0], color='red')
plt.plot([0.02,0.02],[-0.1,0.20], color='blue')
plt.text(0.005, 0.015, '2qDelay>CX', fontdict={'size':20})
plt.text(0.02, -0.0025, '2qDelay<CX',fontdict={'size':20})
plt.text(0.015, -0.02, 'CX threshold',fontdict={'size':20,'weight':'bold','color':'blue'})
ax.set_title('CX,2qDelay Correlation')
ax.set_xlabel('CXerror')
ax.set_ylabel('2qDelay-CX')
plt.show()
